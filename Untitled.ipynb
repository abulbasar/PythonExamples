# %%
from stock import Stock

# %%
content = open("/data/stocks.small.csv").read()
data = content.split("\n")[1:-1]
records = []
for line in data:
    stock = Stock(line)
    records.append(stock)

# %%
records[:5]
# Out:
# [2000-07-18 00:00:00 INTC 50.155473,
#  2000-07-20 00:00:00 BEN 8.789734,
#  2000-07-24 00:00:00 APH 7.689567,
#  2000-07-26 00:00:00 SHW 15.61832,
#  2000-07-26 00:00:00 STJ 9.402721]

# %%
records[0] == records[0]
# Out:
# True

# %%
records[0] == records[1]
# Out:
# False

# %%
records
# Out:
# [2000-07-18 00:00:00 INTC 50.155473,
#  2000-07-20 00:00:00 BEN 8.789734,
#  2000-07-24 00:00:00 APH 7.689567,
#  2000-07-26 00:00:00 SHW 15.61832,
#  2000-07-26 00:00:00 STJ 9.402721,
#  2000-07-31 00:00:00 GGP 5.063753,
#  2000-08-07 00:00:00 SBUX 4.869542,
#  2000-08-09 00:00:00 EQT 10.495977,
#  2000-08-10 00:00:00 BCR 22.539051,
#  2000-08-15 00:00:00 BEN 9.082726,
#  2000-08-23 00:00:00 NKE 4.203095,
#  2000-09-12 00:00:00 IPG 32.285666,
#  2000-09-13 00:00:00 EXC 15.66107,
#  2000-09-22 00:00:00 BXP 20.370235,
#  2000-10-02 00:00:00 BIIB 52.333328,
#  2000-10-04 00:00:00 DD 24.935551,
#  2000-10-05 00:00:00 NUE 4.943182,
#  2000-10-23 00:00:00 ALK 5.26093,
#  2000-10-25 00:00:00 COG 1.571407,
#  2000-10-31 00:00:00 ETN 8.058698,
#  2000-11-01 00:00:00 DO 19.415772,
#  2000-11-02 00:00:00 BSX 8.0625,
#  2000-11-02 00:00:00 UPS 42.092816,
#  2000-11-03 00:00:00 ENDP 7.0625,
#  2000-11-10 00:00:00 WBA 34.890409,
#  2000-11-16 00:00:00 PXD 13.8499,
# ...
