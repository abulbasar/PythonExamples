# %%
import pandas as pd

# %%
df = pd.read_csv("/data/stocks.small.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#          date       open        high         low     close      volume  \
# 0  2000-07-18  144.81250  144.828125  141.437500  143.0000  50683600.0
# 1  2000-07-20   32.93751   34.250010   32.812500   33.7500   3288300.0
# 2  2000-07-24   64.25000   67.312477   64.187523   64.7500    948800.0
# 3  2000-07-26   21.87500   22.125000   20.937500   20.9375   1464300.0
# 4  2000-07-26   42.00000   42.312481   41.625000   41.8750   1397600.0
#
#     adjclose symbol
# 0  50.155473   INTC
# 1   8.789734    BEN
# 2   7.689567    APH
# 3  15.618320    SHW
# 4   9.402721    STJ

# %%
df.head(10)
# Out:
#          date        open        high         low       close      volume  \
# 0  2000-07-18  144.812500  144.828125  141.437500  143.000000  50683600.0
# 1  2000-07-20   32.937510   34.250010   32.812500   33.750000   3288300.0
# 2  2000-07-24   64.250000   67.312477   64.187523   64.750000    948800.0
# 3  2000-07-26   21.875000   22.125000   20.937500   20.937500   1464300.0
# 4  2000-07-26   42.000000   42.312481   41.625000   41.875000   1397600.0
# 5  2000-07-31   33.937519   33.999986   33.750000   33.875011    273400.0
# 6  2000-08-07   41.375038   43.000000   40.812481   42.812481  24337600.0
# 7  2000-08-09   55.562481   55.625000   54.500000   55.000000    387600.0
# 8  2000-08-10   49.000000   52.625000   48.750000   52.125000   1511600.0
# 9  2000-08-15   35.687490   35.687490   34.875000   34.875000   1246500.0
#
#     adjclose symbol
# 0  50.155473   INTC
# 1   8.789734    BEN
# 2   7.689567    APH
# 3  15.618320    SHW
# 4   9.402721    STJ
# 5   5.063753    GGP
# ...

# %%
df.tail()
# Out:
#             date        open        high         low       close     volume  \
# 1841  2016-07-29  114.089996  116.550003  114.089996  115.209999  2520700.0
# 1842  2016-08-01  128.809998  130.020004  127.830002  128.220001  1576600.0
# 1843  2016-08-02   24.340000   24.430000   23.990000   24.170000  7115500.0
# 1844  2016-08-02   63.779999   63.840000   62.490002   62.840000  2740500.0
# 1845  2016-08-04   28.010000   28.190001   27.900000   28.049999  3899900.0
#
#         adjclose symbol
# 1841  115.209999    AET
# 1842  128.220001    UHS
# 1843   24.170000    BSX
# 1844   62.840000    ADI
# 1845   28.049999    CSX

# %%
df.tail(10)
# Out:
#             date        open        high         low       close     volume  \
# 1836  2016-07-12   17.209999   17.299999   16.969999   17.160000  9559600.0
# 1837  2016-07-22  142.589996  143.889999  142.130005  143.770004   830000.0
# 1838  2016-07-26   47.389999   47.599998   46.619999   46.650002  2424000.0
# 1839  2016-07-27   73.589996   73.949997   73.339996   73.360001  1534400.0
# 1840  2016-07-28   37.470001   37.639999   37.139999   37.470001  6339300.0
# 1841  2016-07-29  114.089996  116.550003  114.089996  115.209999  2520700.0
# 1842  2016-08-01  128.809998  130.020004  127.830002  128.220001  1576600.0
# 1843  2016-08-02   24.340000   24.430000   23.990000   24.170000  7115500.0
# 1844  2016-08-02   63.779999   63.840000   62.490002   62.840000  2740500.0
# 1845  2016-08-04   28.010000   28.190001   27.900000   28.049999  3899900.0
#
#         adjclose symbol
# 1836   17.160000    HST
# 1837  143.770004     GD
# 1838   46.400002    CAG
# 1839   73.360001    AFL
# ...

# %%
df.sample(5)
# Out:
#             date        open        high         low       close      volume  \
# 94    2001-08-07   78.500000   79.879997   78.349998   78.650002    914600.0
# 1569  2014-05-15  100.639999  100.839996  100.410004  100.690002   7007600.0
# 1035  2009-12-10   21.750000   22.200001   21.660000   21.760000   1551200.0
# 1139  2010-12-27   30.910000   31.340000   30.780001   31.209999  13823700.0
# 1626  2014-11-06   79.269997   79.809998   78.860001   79.599998   1544900.0
#
#        adjclose symbol
# 94    52.179692     XL
# 1569  94.474160    JNJ
# 1035  18.017033    AWK
# 1139  26.866543    WFC
# 1626  77.049197    CAH

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1846 entries, 0 to 1845
# Data columns (total 8 columns):
# date        1846 non-null object
# open        1846 non-null float64
# high        1846 non-null float64
# low         1846 non-null float64
# close       1846 non-null float64
# volume      1846 non-null float64
# adjclose    1846 non-null float64
# symbol      1846 non-null object
# dtypes: float64(6), object(2)
# memory usage: 115.5+ KB

# %%
import sys

# %%
sys.getsizeof(df)
# Out:
# 323585

# %%
df.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'adjclose', 'symbol'], dtype='object')

# %%
df.dtypes
# Out:
# date         object
# open        float64
# high        float64
# low         float64
# close       float64
# volume      float64
# adjclose    float64
# symbol       object
# dtype: object

# %%
df.iloc[100:105,:]
# Out:
#            date       open       high        low      close      volume  \
# 100  2001-09-06  41.299999  41.520000  40.410000  40.500000  18420100.0
# 101  2001-09-17  49.889999  49.900002  46.349998  46.849998   4339200.0
# 102  2001-09-17  27.000000  27.000000  25.750000  25.750000     17700.0
# 103  2001-09-25  76.000000  77.599998  76.000000  77.199997   3656100.0
# 104  2001-09-25  38.700001  38.700001  36.549999  37.759998   2379800.0
#
#       adjclose symbol
# 100  24.854921     GE
# 101   5.856250   CERN
# 102  16.412830    SJM
# 103  45.782497    LLY
# 104  13.746498     DE

# %%
df.iloc[100:105,:3]
# Out:
#            date       open       high
# 100  2001-09-06  41.299999  41.520000
# 101  2001-09-17  49.889999  49.900002
# 102  2001-09-17  27.000000  27.000000
# 103  2001-09-25  76.000000  77.599998
# 104  2001-09-25  38.700001  38.700001

# %%
df.iloc[100:105,-3:]
# Out:
#          volume   adjclose symbol
# 100  18420100.0  24.854921     GE
# 101   4339200.0   5.856250   CERN
# 102     17700.0  16.412830    SJM
# 103   3656100.0  45.782497    LLY
# 104   2379800.0  13.746498     DE

# %%
s = [4, 5, 7, 8,9]

s[:2]
# Out:
# [4, 5]

# %%
s[-2:]
# Out:
# [8, 9]

# %%
type(df.symbol)
# Out:
# pandas.core.series.Series

# %%
df["symbol"][:10]
# Out:
# 0    INTC
# 1     BEN
# 2     APH
# 3     SHW
# 4     STJ
# 5     GGP
# 6    SBUX
# 7     EQT
# 8     BCR
# 9     BEN
# Name: symbol, dtype: object

# %%
df[["symbol", "date"]].head()
# Out:
#   symbol        date
# 0   INTC  2000-07-18
# 1    BEN  2000-07-20
# 2    APH  2000-07-24
# 3    SHW  2000-07-26
# 4    STJ  2000-07-26

# %%
df.iloc[:, [3, 7]].head()
# Out:
#           low symbol
# 0  141.437500   INTC
# 1   32.812500    BEN
# 2   64.187523    APH
# 3   20.937500    SHW
# 4   41.625000    STJ

# %%
df.symbol.unique()
# Out:
# array(['INTC', 'BEN', 'APH', 'SHW', 'STJ', 'GGP', 'SBUX', 'EQT', 'BCR',
#        'NKE', 'IPG', 'EXC', 'BXP', 'BIIB', 'DD', 'NUE', 'ALK', 'COG',
#        'ETN', 'DO', 'BSX', 'UPS', 'ENDP', 'WBA', 'PXD', 'STI', 'FDX',
#        'LLTC', 'RHT', 'O', 'RAI', 'BWA', 'FLIR', 'MET', 'XLNX', 'FCX',
#        'FOX', 'EMC', 'RHI', 'FISV', 'CINF', 'AGN', 'IP', 'KSS', 'EBAY',
#        'CMS', 'TROW', 'KR', 'R', 'PNC', 'ED', 'KEY', 'USB', 'MCO', 'HES',
#        'RCL', 'HON', 'REGN', 'FLR', 'MSI', 'ISRG', 'MYL', 'LEG', 'MOS',
#        'WMT', 'HD', 'COF', 'MLM', 'ADBE', 'OKE', 'SRE', 'CTAS', 'MMC',
#        'FMC', 'LLL', 'VMC', 'SLB', 'LRCX', 'SCG', 'SYK', 'BLL', 'CERN',
#        'ECL', 'HST', 'GILD', 'XL', 'CTXS', 'AIV', 'GLW', 'GE', 'SJM',
#        'LLY', 'DE', 'HUM', 'EMN', 'F', 'COH', 'MRK', 'PGR', 'AMZN', 'OXY',
#        'DTE', 'ATVI', 'YUM', 'YHOO', 'NTRS', 'SLG', 'MTB', 'COL', 'GS',
#        'CNP', 'IFF', 'ETFC', 'MU', 'MKC', 'EA', 'CCL', 'LMT', 'AIG',
# ...

# %%
df.symbol.value_counts()
# Out:
# ZBH      11
# UPS      11
# K        10
# PHM       9
# KR        9
# COF       9
# FLIR      9
# D         9
# KMB       8
# SIG       8
# CMI       8
# EXR       8
# NUE       8
# IFF       8
# JNJ       8
# NKE       8
# ETN       8
# PPG       8
# FMC       8
# WMT       8
# WDC       7
# BMY       7
# BBBY      7
# SYY       7
# RL        7
# ALK       7
# WFC       7
# VZ        7
# LNC       7
# SCHW      7
#          ..
# NTAP      1
# UA        1
# TWX       1
# RCL       1
# KEY       1
# XRX       1
# NVDA      1
# PNR       1
# L         1
# RIG       1
# MPC       1
# FB        1
# OI        1
# SPGI      1
# ROST      1
# T         1
# CMG       1
# DHR       1
# WRK       1
# GOOGL     1
# SEE       1
# COST      1
# SRCL      1
# MNK       1
# DD        1
# TXN       1
# OMC       1
# MUR       1
# CMCSA     1
# HBI       1
# Name: symbol, Length: 471, dtype: int64

# %%
df.symbol.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9        True
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 1816     True
# 1817     True
# 1818     True
# 1819     True
# 1820     True
# 1821     True
# 1822     True
# 1823     True
# 1824     True
# 1825     True
# 1826     True
# 1827     True
# 1828     True
# 1829     True
# 1830     True
# 1831     True
# 1832     True
# 1833     True
# 1834     True
# 1835     True
# 1836     True
# 1837     True
# 1838     True
# 1839     True
# 1840     True
# 1841     True
# 1842     True
# 1843     True
# 1844     True
# 1845     True
# ...

# %%
df.iloc[[9], :]
# Out:
#          date      open      high     low   close     volume  adjclose symbol
# 9  2000-08-15  35.68749  35.68749  34.875  34.875  1246500.0  9.082726    BEN

# %%
df.iloc[:10,:]
# Out:
#          date        open        high         low       close      volume  \
# 0  2000-07-18  144.812500  144.828125  141.437500  143.000000  50683600.0
# 1  2000-07-20   32.937510   34.250010   32.812500   33.750000   3288300.0
# 2  2000-07-24   64.250000   67.312477   64.187523   64.750000    948800.0
# 3  2000-07-26   21.875000   22.125000   20.937500   20.937500   1464300.0
# 4  2000-07-26   42.000000   42.312481   41.625000   41.875000   1397600.0
# 5  2000-07-31   33.937519   33.999986   33.750000   33.875011    273400.0
# 6  2000-08-07   41.375038   43.000000   40.812481   42.812481  24337600.0
# 7  2000-08-09   55.562481   55.625000   54.500000   55.000000    387600.0
# 8  2000-08-10   49.000000   52.625000   48.750000   52.125000   1511600.0
# 9  2000-08-15   35.687490   35.687490   34.875000   34.875000   1246500.0
#
#     adjclose symbol
# 0  50.155473   INTC
# 1   8.789734    BEN
# 2   7.689567    APH
# 3  15.618320    SHW
# 4   9.402721    STJ
# 5   5.063753    GGP
# ...

# %%
df.drop_duplicates("symbol", keep="last")
# Out:
#             date        open        high         low       close      volume  \
# 15    2000-10-04   44.375001   46.500001   44.375001   45.374998   6005600.0
# 53    2001-02-21   26.299999   26.850000   26.219999   26.230000    678700.0
# 57    2001-03-07   27.900000   27.900000   27.280001   27.290001    288900.0
# 178   2002-04-10   59.700001   64.230003   59.610001   63.509998   2415200.0
# 207   2002-07-12   39.419998   39.689999   37.119999   37.119999  11695200.0
# 223   2002-09-23    6.830000    6.840000    6.500000    6.670000   3019200.0
# 259   2003-02-10   11.410000   11.800000   11.380000   11.750000  33763500.0
# 261   2003-02-20   26.799999   27.129999   26.610001   27.000000   2108400.0
# 283   2003-04-21   76.099998   76.820000   75.900002   76.349998   3176100.0
# 324   2003-08-19   77.599998   77.769997   76.849998   77.000000    478700.0
# 343   2003-10-06   39.750000   40.660000   39.599998   40.389999   7381600.0
# ...

# %%
df["year"] = df.date.str[:4]

# %%
df
# Out:
#             date        open        high         low       close      volume  \
# 0     2000-07-18  144.812500  144.828125  141.437500  143.000000  50683600.0
# 1     2000-07-20   32.937510   34.250010   32.812500   33.750000   3288300.0
# 2     2000-07-24   64.250000   67.312477   64.187523   64.750000    948800.0
# 3     2000-07-26   21.875000   22.125000   20.937500   20.937500   1464300.0
# 4     2000-07-26   42.000000   42.312481   41.625000   41.875000   1397600.0
# 5     2000-07-31   33.937519   33.999986   33.750000   33.875011    273400.0
# 6     2000-08-07   41.375038   43.000000   40.812481   42.812481  24337600.0
# 7     2000-08-09   55.562481   55.625000   54.500000   55.000000    387600.0
# 8     2000-08-10   49.000000   52.625000   48.750000   52.125000   1511600.0
# 9     2000-08-15   35.687490   35.687490   34.875000   34.875000   1246500.0
# 10    2000-08-23   41.125000   41.375000   40.187519   40.250000  19686400.0
# ...

# %%
df[df.duplicated(["symbol", "year"])]
# Out:
#             date        open        high         low       close      volume  \
# 9     2000-08-15   35.687490   35.687490   34.875000   34.875000   1246500.0
# 37    2000-12-22   44.812500   48.812500   44.312500   48.375000   9779200.0
# 73    2001-05-21    6.300000    6.320000    6.120000    6.270000     52000.0
# 74    2001-05-23   87.380013   87.480000   85.620003   85.809992   1710300.0
# 89    2001-07-23   29.750000   29.750000   28.440001   28.600000    104900.0
# 98    2001-08-29   61.200001   62.450081   59.880001   61.549919  31905600.0
# 100   2001-09-06   41.299999   41.520000   40.410000   40.500000  18420100.0
# 101   2001-09-17   49.889999   49.900002   46.349998   46.849998   4339200.0
# 109   2001-10-08   55.830002   55.840000   54.380001   55.360001   1531700.0
# 114   2001-10-12   37.910000   38.240002   37.549999   38.130001   1231000.0
# 116   2001-10-15   68.000000   68.849998   66.250000   68.599998   1168800.0
# ...

# %%
df[df.symbol == "BEN"]
# Out:
#             date        open        high         low       close     volume  \
# 1     2000-07-20   32.937510   34.250010   32.812500   33.750000  3288300.0
# 9     2000-08-15   35.687490   35.687490   34.875000   34.875000  1246500.0
# 435   2004-09-15   55.250010   55.430008   55.059992   55.070011  2503500.0
# 687   2006-10-30  111.170013  114.159988  110.960014  113.459999  5225400.0
# 807   2007-12-28  114.860012  115.820011  113.240009  114.140007  2376600.0
# 1767  2015-12-23   36.110001   37.500000   36.009998   37.360001  5262000.0
#
#        adjclose symbol  year
# 1      8.789734    BEN  2000
# 9      9.082726    BEN  2000
# 435   14.730094    BEN  2004
# 687   31.629432    BEN  2006
# 807   32.030168    BEN  2007
# 1767  36.788220    BEN  2015

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1846 entries, 0 to 1845
# Data columns (total 9 columns):
# date        1846 non-null object
# open        1846 non-null float64
# high        1846 non-null float64
# low         1846 non-null float64
# close       1846 non-null float64
# volume      1846 non-null float64
# adjclose    1846 non-null float64
# symbol      1846 non-null object
# year        1846 non-null object
# dtypes: float64(6), object(3)
# memory usage: 129.9+ KB

# %%
df[(df.symbol == "BEN") & (df.year == "2000")]
# Out:
#          date      open      high      low   close     volume  adjclose  \
# 1  2000-07-20  32.93751  34.25001  32.8125  33.750  3288300.0  8.789734
# 9  2000-08-15  35.68749  35.68749  34.8750  34.875  1246500.0  9.082726
#
#   symbol  year
# 1    BEN  2000
# 9    BEN  2000

# %%
df.query("symbol == 'BEN' and year == '2000'")
# Out:
#          date      open      high      low   close     volume  adjclose  \
# 1  2000-07-20  32.93751  34.25001  32.8125  33.750  3288300.0  8.789734
# 9  2000-08-15  35.68749  35.68749  34.8750  34.875  1246500.0  9.082726
#
#   symbol  year
# 1    BEN  2000
# 9    BEN  2000

# %%
df.query("symbol == 'BEN' and year == 2000")
# Out:
# Empty DataFrame
# Columns: [date, open, high, low, close, volume, adjclose, symbol, year]
# Index: []

# %%
df["year"] = df.year.astype("int")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1846 entries, 0 to 1845
# Data columns (total 9 columns):
# date        1846 non-null object
# open        1846 non-null float64
# high        1846 non-null float64
# low         1846 non-null float64
# close       1846 non-null float64
# volume      1846 non-null float64
# adjclose    1846 non-null float64
# symbol      1846 non-null object
# year        1846 non-null int64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 129.9+ KB

# %%
df[(df.symbol == "BEN") & (df.year == 2000)]
# Out:
#          date      open      high      low   close     volume  adjclose  \
# 1  2000-07-20  32.93751  34.25001  32.8125  33.750  3288300.0  8.789734
# 9  2000-08-15  35.68749  35.68749  34.8750  34.875  1246500.0  9.082726
#
#   symbol  year
# 1    BEN  2000
# 9    BEN  2000

# %%
"2" == 2
# Out:
# False

# %%
df.query("symbol == 'BEN' and year == 2000")
# Out:
#          date      open      high      low   close     volume  adjclose  \
# 1  2000-07-20  32.93751  34.25001  32.8125  33.750  3288300.0  8.789734
# 9  2000-08-15  35.68749  35.68749  34.8750  34.875  1246500.0  9.082726
#
#   symbol  year
# 1    BEN  2000
# 9    BEN  2000

# %%
df.query("symbol == 'BEN' and year == 2000.0")
# Out:
#          date      open      high      low   close     volume  adjclose  \
# 1  2000-07-20  32.93751  34.25001  32.8125  33.750  3288300.0  8.789734
# 9  2000-08-15  35.68749  35.68749  34.8750  34.875  1246500.0  9.082726
#
#   symbol  year
# 1    BEN  2000
# 9    BEN  2000

# %%
2000 == 2000.0
# Out:
# True

# %%
2000 == 2000.1
# Out:
# False

# %%
int(2000.1)
# Out:
# 2000

# %%
len(df.query("symbol == 'BEN' and year == 2000.0"))
# Out:
# 2

# %%
df.query("symbol == 'BEN' and year == 2000.0").shape[0]
# Out:
# 2

# %%
df["pct"] = (df["close"] - df["open"])/df["open"]
df.head()
# Out:
#          date       open        high         low     close      volume  \
# 0  2000-07-18  144.81250  144.828125  141.437500  143.0000  50683600.0
# 1  2000-07-20   32.93751   34.250010   32.812500   33.7500   3288300.0
# 2  2000-07-24   64.25000   67.312477   64.187523   64.7500    948800.0
# 3  2000-07-26   21.87500   22.125000   20.937500   20.9375   1464300.0
# 4  2000-07-26   42.00000   42.312481   41.625000   41.8750   1397600.0
#
#     adjclose symbol  year       pct
# 0  50.155473   INTC  2000 -0.012516
# 1   8.789734    BEN  2000  0.024668
# 2   7.689567    APH  2000  0.007782
# 3  15.618320    SHW  2000 -0.042857
# 4   9.402721    STJ  2000 -0.002976

# %%
df.sort_values("pct", ascending = False)[:3]
# Out:
#            date       open       high    low      close      volume  \
# 894  2008-10-13  19.799999  22.100000  19.23  22.100000   5260800.0
# 871  2008-07-16  30.049999  33.240002  30.01  33.209999  10548800.0
# 132  2001-12-05   8.500000   9.350000   8.49   9.350000    480400.0
#
#       adjclose symbol  year       pct
# 894   5.330276    ALK  2008  0.116162
# 871  27.081553    CCL  2008  0.105158
# 132  93.500001   ETFC  2001  0.100000

# %%
pd.options.display.precision = 4

# %%
df.sort_values("pct", ascending = False)[:3]
# Out:
#            date   open   high    low  close      volume  adjclose symbol  \
# 894  2008-10-13  19.80  22.10  19.23  22.10  5.2608e+06    5.3303    ALK
# 871  2008-07-16  30.05  33.24  30.01  33.21  1.0549e+07   27.0816    CCL
# 132  2001-12-05   8.50   9.35   8.49   9.35  4.8040e+05   93.5000   ETFC
#
#      year     pct
# 894  2008  0.1162
# 871  2008  0.1052
# 132  2001  0.1000

# %%
df.groupby("symbol").volume.mean().sort_values(ascending = False)
# Out:
# symbol
# BAC      1.8500e+08
# AAPL     1.6637e+08
# INTC     7.4369e+07
# FB       6.0000e+07
# F        4.5860e+07
# MSFT     4.1910e+07
# T        3.8324e+07
# EBAY     3.7022e+07
# HPQ      3.6500e+07
# CSCO     3.4011e+07
# ORCL     3.3764e+07
# GOOGL    3.0898e+07
# C        3.0418e+07
# JPM      2.8355e+07
# XOM      2.7768e+07
# PFE      2.5643e+07
# AMAT     2.4337e+07
# DAL      2.3105e+07
# YHOO     2.3084e+07
# WFC      2.1810e+07
# AA       2.1780e+07
# SBUX     2.1040e+07
# NVDA     2.0537e+07
# USB      2.0442e+07
# GE       1.9689e+07
# TXN      1.9349e+07
# QCOM     1.8620e+07
# GILD     1.7850e+07
# GLW      1.6825e+07
# PEP      1.6810e+07
#             ...
# SLG      5.6880e+05
# BXP      5.6186e+05
# MTB      5.5800e+05
# SIG      5.2251e+05
# ALB      5.1752e+05
# CINF     5.1187e+05
# SCG      5.0964e+05
# AMG      5.0050e+05
# MHK      4.8817e+05
# PVH      4.8550e+05
# ALLE     4.7110e+05
# AYI      4.6954e+05
# MLM      4.4693e+05
# REGN     4.4394e+05
# ...

# %%
df.groupby(["symbol", "year"]).volume.mean()
# Out:
# symbol  year
# A       2007    3.4078e+06
#         2009    6.2278e+06
# AA      2004    6.3699e+06
#         2010    4.4190e+07
#         2014    1.9897e+07
#         2015    1.9221e+07
# AAL     2006    2.5989e+06
# AAP     2006    6.3040e+05
#         2008    9.5890e+05
#         2010    3.1198e+06
#         2013    8.3105e+05
# AAPL    2006    2.5121e+08
#         2012    2.0583e+08
#         2016    4.2062e+07
# ABC     2010    1.9746e+06
#         2014    1.6818e+06
# ABT     2003    1.2537e+07
#         2010    2.0577e+07
#         2015    7.1407e+06
#         2016    1.3025e+07
# ACN     2003    2.9602e+06
#         2014    3.4375e+06
# ADBE    2001    4.2062e+06
#         2011    5.2452e+06
# ADI     2002    2.9222e+06
#         2003    3.4052e+06
#         2007    4.0273e+06
#         2013    1.8529e+06
#         2015    2.5066e+06
#         2016    2.7405e+06
#                    ...
# XOM     2003    7.4492e+06
#         2007    2.9229e+07
#         2009    4.6627e+07
# ...

# %%
df.groupby(["symbol", "year"]).pct.agg(["min", "max"])
# Out:
#                 min     max
# symbol year
# A      2007  0.0098  0.0098
#        2009 -0.0112 -0.0112
# AA     2004  0.0353  0.0353
#        2010 -0.0269 -0.0269
#        2014  0.0169  0.0169
#        2015 -0.0038  0.0025
# AAL    2006 -0.0356 -0.0356
# AAP    2006  0.0051  0.0051
#        2008 -0.0015 -0.0015
#        2010  0.0474  0.0474
#        2013 -0.0027  0.0108
# AAPL   2006 -0.0332 -0.0332
#        2012  0.0463  0.0463
#        2016  0.0042  0.0042
# ABC    2010  0.0057  0.0057
#        2014 -0.0047 -0.0047
# ABT    2003  0.0059  0.0145
#        2010 -0.0038 -0.0038
#        2015 -0.0004 -0.0004
#        2016 -0.0064  0.0013
# ACN    2003 -0.0153 -0.0153
#        2014  0.0225  0.0225
# ADBE   2001 -0.0589 -0.0589
#        2011  0.0056  0.0056
# ADI    2002 -0.0364 -0.0364
#        2003  0.0214  0.0214
#        2007  0.0038  0.0038
#        2013  0.0049  0.0049
#        2015 -0.0311 -0.0311
#        2016 -0.0147 -0.0147
# ...             ...     ...
# ...

# %%
df.groupby(["symbol", "year"])["pct","volume"].agg(["min", "max"])
# Out:
#                 pct              volume
#                 min     max         min         max
# symbol year
# A      2007  0.0098  0.0098  3.4078e+06  3.4078e+06
#        2009 -0.0112 -0.0112  6.2278e+06  6.2278e+06
# AA     2004  0.0353  0.0353  6.3699e+06  6.3699e+06
#        2010 -0.0269 -0.0269  4.4190e+07  4.4190e+07
#        2014  0.0169  0.0169  1.9897e+07  1.9897e+07
#        2015 -0.0038  0.0025  1.9107e+07  1.9336e+07
# AAL    2006 -0.0356 -0.0356  2.5989e+06  2.5989e+06
# AAP    2006  0.0051  0.0051  6.3040e+05  6.3040e+05
#        2008 -0.0015 -0.0015  9.5890e+05  9.5890e+05
#        2010  0.0474  0.0474  3.1198e+06  3.1198e+06
#        2013 -0.0027  0.0108  7.2030e+05  9.4180e+05
# AAPL   2006 -0.0332 -0.0332  2.5121e+08  2.5121e+08
#        2012  0.0463  0.0463  2.0583e+08  2.0583e+08
#        2016  0.0042  0.0042  4.2062e+07  4.2062e+07
# ABC    2010  0.0057  0.0057  1.9746e+06  1.9746e+06
#        2014 -0.0047 -0.0047  1.6818e+06  1.6818e+06
# ...

# %%
df.groupby(["symbol", "year"]).agg({"pct": ["min", "max"], "volume": "mean"})
# Out:
#                 pct              volume
#                 min     max        mean
# symbol year
# A      2007  0.0098  0.0098  3.4078e+06
#        2009 -0.0112 -0.0112  6.2278e+06
# AA     2004  0.0353  0.0353  6.3699e+06
#        2010 -0.0269 -0.0269  4.4190e+07
#        2014  0.0169  0.0169  1.9897e+07
#        2015 -0.0038  0.0025  1.9221e+07
# AAL    2006 -0.0356 -0.0356  2.5989e+06
# AAP    2006  0.0051  0.0051  6.3040e+05
#        2008 -0.0015 -0.0015  9.5890e+05
#        2010  0.0474  0.0474  3.1198e+06
#        2013 -0.0027  0.0108  8.3105e+05
# AAPL   2006 -0.0332 -0.0332  2.5121e+08
#        2012  0.0463  0.0463  2.0583e+08
#        2016  0.0042  0.0042  4.2062e+07
# ABC    2010  0.0057  0.0057  1.9746e+06
#        2014 -0.0047 -0.0047  1.6818e+06
# ABT    2003  0.0059  0.0145  1.2537e+07
#        2010 -0.0038 -0.0038  2.0577e+07
#        2015 -0.0004 -0.0004  7.1407e+06
#        2016 -0.0064  0.0013  1.3025e+07
# ACN    2003 -0.0153 -0.0153  2.9602e+06
# ...

# %%
def my_fun(values):
    return sum(values)

# %%
agg = df.groupby(["symbol", "year"]).agg({"pct": ["min", "max", "sum", my_fun, "count"], "volume": "mean"})
agg
# Out:
#                 pct                                    volume
#                 min     max     sum  my_fun count        mean
# symbol year
# A      2007  0.0098  0.0098  0.0098  0.0098     1  3.4078e+06
#        2009 -0.0112 -0.0112 -0.0112 -0.0112     1  6.2278e+06
# AA     2004  0.0353  0.0353  0.0353  0.0353     1  6.3699e+06
#        2010 -0.0269 -0.0269 -0.0269 -0.0269     1  4.4190e+07
#        2014  0.0169  0.0169  0.0169  0.0169     1  1.9897e+07
#        2015 -0.0038  0.0025 -0.0013 -0.0013     2  1.9221e+07
# AAL    2006 -0.0356 -0.0356 -0.0356 -0.0356     1  2.5989e+06
# AAP    2006  0.0051  0.0051  0.0051  0.0051     1  6.3040e+05
#        2008 -0.0015 -0.0015 -0.0015 -0.0015     1  9.5890e+05
#        2010  0.0474  0.0474  0.0474  0.0474     1  3.1198e+06
#        2013 -0.0027  0.0108  0.0080  0.0080     2  8.3105e+05
# AAPL   2006 -0.0332 -0.0332 -0.0332 -0.0332     1  2.5121e+08
#        2012  0.0463  0.0463  0.0463  0.0463     1  2.0583e+08
# ...

# %%
agg[agg["pct"]["count"] ==2]
# Out:
#                 pct                                    volume
#                 min     max     sum  my_fun count        mean
# symbol year
# AA     2015 -0.0038  0.0025 -0.0013 -0.0013     2  1.9221e+07
# AAP    2013 -0.0027  0.0108  0.0080  0.0080     2  8.3105e+05
# ABT    2003  0.0059  0.0145  0.0205  0.0205     2  1.2537e+07
#        2016 -0.0064  0.0013 -0.0051 -0.0051     2  1.3025e+07
# ADS    2014 -0.0065  0.0150  0.0085  0.0085     2  8.6635e+05
# AES    2003  0.0000  0.0273  0.0273  0.0273     2  2.9556e+06
# AIV    2012  0.0004  0.0110  0.0113  0.0113     2  1.1784e+06
# AIZ    2008 -0.0033  0.0032 -0.0001 -0.0001     2  1.7358e+06
# ALB    2015 -0.0100 -0.0021 -0.0122 -0.0122     2  5.9655e+05
# AMP    2012 -0.0225 -0.0116 -0.0341 -0.0341     2  1.9658e+06
# AMT    2005 -0.0093  0.0041 -0.0053 -0.0053     2  2.0879e+06
# AMZN   2015 -0.0149 -0.0016 -0.0164 -0.0164     2  3.8104e+06
# AON    2003  0.0308  0.0438  0.0746  0.0746     2  1.2436e+06
# ...

# %%
df = pd.read_csv("/Users/abasar/Downloads/ASTRAZEN.csv")
df.head()
# Out:
#      Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0  ASTRAZEN     EQ  02-Aug-2017      915.30       919.0      922.05
# 1  ASTRAZEN     EQ  03-Aug-2017      917.60       915.0      921.00
# 2  ASTRAZEN     EQ  04-Aug-2017      909.65       915.0      916.75
# 3  ASTRAZEN     EQ  07-Aug-2017      909.50       901.0      924.75
# 4  ASTRAZEN     EQ  08-Aug-2017      914.25       909.6      932.00
#
#    Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0     910.00      914.00       917.60         915.75                   3420
# 1     906.00      906.00       909.65         913.16                   2007
# 2     902.45      906.55       909.50         908.63                   3469
# 3     901.00      916.00       914.25         913.65                   1777
# 4     891.25      897.95       895.95         903.97                   5018
#
#      Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
date_index = pd.to_datetime(df["Date"])
date_index
# Out:
# 0     2017-08-02
# 1     2017-08-03
# 2     2017-08-04
# 3     2017-08-07
# 4     2017-08-08
# 5     2017-08-09
# 6     2017-08-10
# 7     2017-08-11
# 8     2017-08-14
# 9     2017-08-16
# 10    2017-08-17
# 11    2017-08-18
# 12    2017-08-21
# 13    2017-08-22
# 14    2017-08-23
# 15    2017-08-24
# 16    2017-08-28
# 17    2017-08-29
# 18    2017-08-30
# 19    2017-08-31
# 20    2017-09-01
# 21    2017-09-04
# 22    2017-09-05
# 23    2017-09-06
# 24    2017-09-07
# 25    2017-09-08
# 26    2017-09-11
# 27    2017-09-12
# 28    2017-09-13
# 29    2017-09-14
#          ...
# 465   2019-06-21
# 466   2019-06-24
# 467   2019-06-25
# 468   2019-06-26
# 469   2019-06-27
# 470   2019-06-28
# 471   2019-07-01
# 472   2019-07-02
# 473   2019-07-03
# 474   2019-07-04
# 475   2019-07-05
# 476   2019-07-08
# 477   2019-07-09
# 478   2019-07-10
# 479   2019-07-11
# 480   2019-07-12
# 481   2019-07-15
# 482   2019-07-16
# 483   2019-07-17
# 484   2019-07-18
# 485   2019-07-19
# ...

# %%
df.index = pd.to_datetime(df["Date"])

# %%
df.head()
# Out:
#               Symbol Series         Date  Prev Close  Open Price  High Price  \
# Date
# 2017-08-02  ASTRAZEN     EQ  02-Aug-2017      915.30       919.0      922.05
# 2017-08-03  ASTRAZEN     EQ  03-Aug-2017      917.60       915.0      921.00
# 2017-08-04  ASTRAZEN     EQ  04-Aug-2017      909.65       915.0      916.75
# 2017-08-07  ASTRAZEN     EQ  07-Aug-2017      909.50       901.0      924.75
# 2017-08-08  ASTRAZEN     EQ  08-Aug-2017      914.25       909.6      932.00
#
#             Low Price  Last Price  Close Price  Average Price  \
# Date
# 2017-08-02     910.00      914.00       917.60         915.75
# 2017-08-03     906.00      906.00       909.65         913.16
# 2017-08-04     902.45      906.55       909.50         908.63
# 2017-08-07     901.00      916.00       914.25         913.65
# 2017-08-08     891.25      897.95       895.95         903.97
#
#             Total Traded Quantity    Turnover  No. of Trades  Deliverable Qty  \
# Date
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2017-08-02', '2017-08-03', '2017-08-04', '2017-08-07',
#                '2017-08-08', '2017-08-09', '2017-08-10', '2017-08-11',
#                '2017-08-14', '2017-08-16',
#                ...
#                '2019-07-19', '2019-07-22', '2019-07-23', '2019-07-24',
#                '2019-07-25', '2019-07-26', '2019-07-29', '2019-07-30',
#                '2019-07-31', '2019-08-01'],
#               dtype='datetime64[ns]', name='Date', length=495, freq=None)

# %%
df = df.asfreq("B")

# %%
df.index
# Out:
# DatetimeIndex(['2017-08-02', '2017-08-03', '2017-08-04', '2017-08-07',
#                '2017-08-08', '2017-08-09', '2017-08-10', '2017-08-11',
#                '2017-08-14', '2017-08-15',
#                ...
#                '2019-07-19', '2019-07-22', '2019-07-23', '2019-07-24',
#                '2019-07-25', '2019-07-26', '2019-07-29', '2019-07-30',
#                '2019-07-31', '2019-08-01'],
#               dtype='datetime64[ns]', name='Date', length=522, freq='B')

# %%
price = df[["Close Price"]]
price.head()
# Out:
#             Close Price
# Date
# 2017-08-02       917.60
# 2017-08-03       909.65
# 2017-08-04       909.50
# 2017-08-07       914.25
# 2017-08-08       895.95

# %%
price["rolling_mean"] = price["Close Price"].rolling(3).mean()
price.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#             Close Price  rolling_mean
# Date
# 2017-08-02       917.60           NaN
# 2017-08-03       909.65           NaN
# 2017-08-04       909.50      912.2500
# 2017-08-07       914.25      911.1333
# 2017-08-08       895.95      906.5667

# %%
import numpy as np

# %%
np.mean([917.60, 909.65, 909.50	])
# Out:
# 912.25

# %%
price["rolling_mean_shifted1"] = price["Close Price"].rolling(3).mean().shift(1)
price.head(10)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#             Close Price  rolling_mean  rolling_mean_shifted1
# Date
# 2017-08-02       917.60           NaN                    NaN
# 2017-08-03       909.65           NaN                    NaN
# 2017-08-04       909.50      912.2500                    NaN
# 2017-08-07       914.25      911.1333               912.2500
# 2017-08-08       895.95      906.5667               911.1333
# 2017-08-09       905.10      905.1000               906.5667
# 2017-08-10       905.60      902.2167               905.1000
# 2017-08-11       900.15      903.6167               902.2167
# ...

# %%
df = pd.read_csv("/data/startups.csv")
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df.isna()
# Out:
#     R&D Spend  Administration  Marketing Spend  State  Profit
# 0       False           False            False  False   False
# 1       False           False            False  False   False
# 2       False           False            False  False   False
# 3       False           False            False  False   False
# 4       False           False            False  False   False
# 5       False           False            False  False   False
# 6       False           False            False  False   False
# 7       False           False            False  False   False
# 8       False           False            False  False   False
# 9       False           False            False  False   False
# 10      False           False            False  False   False
# 11      False           False            False  False   False
# 12      False           False            False  False   False
# 13      False           False            False  False   False
# ...

# %%
df.isnull().sum()
# Out:
# R&D Spend          2
# Administration     0
# Marketing Spend    3
# State              0
# Profit             0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 5

# %%
df[df.isnull().sum(axis = 1)>0]
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 19   86419.70       153514.11              NaN    New York  122776.86
# 47        NaN       135426.92              NaN  California   42559.73
# 48     542.05        51743.15              NaN    New York   35673.41
# 49        NaN       116983.80         45173.06  California   14681.40

# %%
df[df[["Marketing Spend"]].isnull().sum(axis = 1)>0]
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 19   86419.70       153514.11              NaN    New York  122776.86
# 47        NaN       135426.92              NaN  California   42559.73
# 48     542.05        51743.15              NaN    New York   35673.41

# %%
df[["Marketing Spend"]]
# Out:
#     Marketing Spend
# 0         471784.10
# 1         443898.53
# 2         407934.54
# 3         383199.62
# 4         366168.42
# 5         362861.36
# 6         127716.82
# 7         323876.68
# 8         311613.29
# 9         304981.62
# 10        229160.95
# 11        249744.55
# 12        249839.44
# 13        252664.93
# 14        256512.92
# 15        261776.23
# 16        264346.06
# 17        282574.31
# 18        294919.57
# 19              NaN
# 20        298664.47
# 21        299737.29
# 22        303319.26
# 23        304768.73
# 24        140574.81
# 25        137962.62
# 26        134050.07
# 27        353183.81
# 28        118148.20
# 29        107138.38
# 30         91131.24
# 31         88218.23
# 32         46085.25
# 33        214634.81
# 34        210797.67
# 35        205517.64
# 36        201126.82
# 37        197029.42
# 38        185265.10
# 39        174999.30
# 40        172795.67
# 41        164470.71
# 42        148001.11
# 43         35534.17
# ...

# %%
price.head()
# Out:
#             Close Price  rolling_mean  rolling_mean_shifted1
# Date
# 2017-08-02       917.60           NaN                    NaN
# 2017-08-03       909.65           NaN                    NaN
# 2017-08-04       909.50      912.2500                    NaN
# 2017-08-07       914.25      911.1333               912.2500
# 2017-08-08       895.95      906.5667               911.1333

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
price["Close Price"].plot()

plt.savefig("az.jpg")
plt.savefig("az.svg")

# %%
df.to_json("/tmp/starups.json.gz", orient="records", compression="gzip")

# %%
pd.read_excel("/Users/abasar/Downloads/insurance.xlsx", sheet_name="insurance")
# Out:
#       age  gender     bmi  children smoker     region     charges
# 0      19  female  27.900         0    yes  southwest  16884.9240
# 1      18    male  33.770         1     no  southeast   1725.5523
# 2      28    male  33.000         3     no  southeast   4449.4620
# 3      33    male  22.705         0     no  northwest  21984.4706
# 4      32    male  28.880         0     no  northwest   3866.8552
# 5      31  female  25.740         0     no  southeast   3756.6216
# 6      46  female  33.440         1     no  southeast   8240.5896
# 7      37  female  27.740         3     no  northwest   7281.5056
# 8      37    male  29.830         2     no  northeast   6406.4107
# 9      60  female  25.840         0     no  northwest  28923.1369
# 10     25    male  26.220         0     no  northeast   2721.3208
# 11     62  female  26.290         0    yes  southeast  27808.7251
# 12     23    male  34.400         0     no  southwest   1826.8430
# ...
