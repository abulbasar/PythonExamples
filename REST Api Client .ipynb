# %%
import requests

# %%
session = requests.Session()

# %%
response = session.get("https://api.github.com/repos/abulbasar/SparkJavaExamples/git/commits/cafa136e960be68866f9428a8cadf37ea21c50bc")

# %%
response.content
# Out:
# b'{"sha":"cafa136e960be68866f9428a8cadf37ea21c50bc","node_id":"MDY6Q29tbWl0OTk4NDcyMTM6Y2FmYTEzNmU5NjBiZTY4ODY2Zjk0MjhhOGNhZGYzN2VhMjFjNTBiYw==","url":"https://api.github.com/repos/abulbasar/SparkJavaExamples/git/commits/cafa136e960be68866f9428a8cadf37ea21c50bc","html_url":"https://github.com/abulbasar/SparkJavaExamples/commit/cafa136e960be68866f9428a8cadf37ea21c50bc","author":{"name":"Abul Basar","email":"abulbasar@gmail.com","date":"2020-05-04T17:55:02Z"},"committer":{"name":"Abul Basar","email":"abulbasar@gmail.com","date":"2020-05-04T17:55:02Z"},"tree":{"sha":"3fae3218e0a51edc0361d8b48bb52ae078a02d80","url":"https://api.github.com/repos/abulbasar/SparkJavaExamples/git/trees/3fae3218e0a51edc0361d8b48bb52ae078a02d80"},"message":"unclean checkin","parents":[{"sha":"f4a8d443caf18a020de5f39efa1bc4439e535ac3","url":"https://api.github.com/repos/abulbasar/SparkJavaExamples/git/commits/f4a8d443caf18a020de5f39efa1bc4439e535ac3","html_url":"https://github.com/abulbasar/SparkJavaExamples/co
# ...

# %%
response = requests.get("http://127.0.0.1:5000/movies/400099")
response
# Out:
# <Response [404]>

# %%
response.text
# Out:
# '{\n  "message": "No movie has been found with 400099", \n  "status": "ERROR"\n}\n'

# %%
response.json()
# Out:
# {'message': 'No movie has been found with 400099', 'status': 'ERROR'}

# %%
response = requests.get("http://127.0.0.1:5000/movies/4000")
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'genres': 'Adventure|Drama', 'movieId': '4000', 'title': 'Bounty, The (1984)'}

# %%
response = requests.get("http://127.0.0.1:5000/movies")
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'records': [{'genres': 'Adventure|Animation|Children|Comedy|Fantasy',
#    'movieId': '1',
#    'title': 'Toy Story (1995)'},
#   {'genres': 'Adventure|Children|Fantasy',
#    'movieId': '2',
#    'title': 'Jumanji (1995)'},
#   {'genres': 'Comedy|Romance',
#    'movieId': '3',
#    'title': 'Grumpier Old Men (1995)'},
#   {'genres': 'Comedy|Drama|Romance',
#    'movieId': '4',
#    'title': 'Waiting to Exhale (1995)'},
#   {'genres': 'Comedy',
#    'movieId': '5',
#    'title': 'Father of the Bride Part II (1995)'},
#   {'genres': 'Action|Crime|Thriller', 'movieId': '6', 'title': 'Heat (1995)'},
#   {'genres': 'Comedy|Romance', 'movieId': '7', 'title': 'Sabrina (1995)'},
#   {'genres': 'Adventure|Children',
#    'movieId': '8',
#    'title': 'Tom and Huck (1995)'},
#   {'genres': 'Action', 'movieId': '9', 'title': 'Sudden Death (1995)'},
#   {'genres': 'Action|Adventure|Thriller',
#    'movieId': '10',
#    'title': 'GoldenEye (1995)'},
#   {'genres': 'Comedy|Drama|Romance',
# ...
